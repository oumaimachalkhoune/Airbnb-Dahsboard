# %% [markdown]
# # ***Upload all library required:***

# %%
import pandas as pd

# %%
from google.colab import files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # ***Upload All Data from different cities:***

# %%
Athens = pd.read_excel('/content/drive/MyDrive/project/Project Bennani/clean dataset for city/Athens.xlsx')

# %%
Barcelona = pd.read_excel('/content/drive/MyDrive/project/Project Bennani/clean dataset for city/Barcelona.xlsx')

# %%
Istanbul = pd.read_excel('/content/drive/MyDrive/project/Project Bennani/clean dataset for city/Istanbul.xlsx')

# %%
London = pd.read_excel('/content/drive/MyDrive/project/Project Bennani/clean dataset for city/London.xlsx')

# %%
Los_Angeles = pd.read_excel('/content/drive/MyDrive/project/Project Bennani/clean dataset for city/Los Angeles.xlsx')

# %%
Montreal = pd.read_excel('/content/drive/MyDrive/project/Project Bennani/clean dataset for city/Montreal.xlsx')

# %%
New_York = pd.read_excel('/content/drive/MyDrive/project/Project Bennani/clean dataset for city/New York City.xlsx')

# %%
Rio_de_janeiro= pd.read_excel('/content/drive/MyDrive/project/Project Bennani/clean dataset for city/Rio de janeiro.xlsx')

# %%
Rome = pd.read_excel('/content/drive/MyDrive/project/Project Bennani/clean dataset for city/Rome.xlsx')

# %%
Tokyo = pd.read_excel('/content/drive/MyDrive/project/Project Bennani/clean dataset for city/Tokyo.xlsx')

# %%
Vienna = pd.read_excel('/content/drive/MyDrive/project/Project Bennani/clean dataset for city/Vienna.xlsx')

# %%
capetown = pd.read_excel('/content/drive/MyDrive/project/Project Bennani/clean dataset for city/cape town.xlsx')

# %% [markdown]
# # ***Merge all data from all cities into one dataset:***

# %%
merged_data = pd.concat([Athens,Barcelona,capetown,Istanbul,London,Los_Angeles,Rio_de_janeiro,Montreal,Rome,New_York,Tokyo,Vienna], ignore_index=True)

# %%
print(merged_data.head())
# Out:
#       id continent country    city  host_id  host_name  latitude longitude  \
# 0  10595    Europe  Greece  Athens    37177  Emmanouil  37.98863  23.76527
# 1  10990    Europe  Greece  Athens    37177  Emmanouil  37.98903  23.76448
# 2  10993    Europe  Greece  Athens    37177  Emmanouil  37.98888  23.76473
# 3  10995    Europe  Greece  Athens    37177  Emmanouil  37.98903  23.76448
# 4  27262    Europe  Greece  Athens    37177  Emmanouil  37.98924    23.765
#
#          room_type  price_bycountry  coverage_rate   price  minimum_nights  \
# 0  Entire home/apt              144           1.06  152.64               1
# 1  Entire home/apt               70           1.06   74.20               1
# 2  Entire home/apt               85           1.06   90.10               1
# 3  Entire home/apt               60           1.06   63.60               1
# 4  Entire home/apt               85           1.06   90.10               1
#
#    availability_365  number_of_reviews  reviews  license
# ...

# %%
print(merged_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365132 entries, 0 to 365131
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 365132 non-null  int64
#  1   continent          365132 non-null  object
#  2   country            365132 non-null  object
#  3   city               365132 non-null  object
#  4   host_id            365132 non-null  int64
#  5   host_name          365132 non-null  object
#  6   latitude           365132 non-null  float64
#  7   longitude          365132 non-null  object
#  8   room_type          365132 non-null  object
#  9   price_bycountry    365132 non-null  int64
#  10  coverage_rate      365132 non-null  float64
#  11  price              365132 non-null  float64
#  12  minimum_nights     365132 non-null  int64
#  13  availability_365   365132 non-null  int64
#  14  number_of_reviews  365132 non-null  int64
# ...

# %%
merged_data.to_csv('data_merged.csv', index=False)

# %%
! dir
# Out:
# data_merged.csv  drive	sample_data

# %% [markdown]
# # ***Download data merged :***

# %%
files.download('data_merged.csv')
